# %%
import pandas as pd

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df  #printing the data set
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.head(10)  # printing the top 10 data set
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.tail(10)  # printing the last 10 dataset
# Out:
#                   area_type   availability               location       size  \
# 13310  Super built-up  Area  Ready To Move           Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move       Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move              Bellandur      2 BHK
# 13313  Super built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price
# 13310      NaN       1050   2.0      2.0   52.71
# ...

# %%
#taking some random sample of data fro the complete datset which is random

df.sample()
# Out:
#                  area_type   availability        location   size  society  \
# 5468  Super built-up  Area  Ready To Move  Sarjapur  Road  2 BHK  S2kaaan
#
#      total_sqft  bath  balcony  price
# 5468       1178   2.0      2.0  40.43

# %%
df.sample(5)
# Out:
#                   area_type   availability         location   size  society  \
# 694    Super built-up  Area  Ready To Move  Prakruthi Nagar  2 BHK  MSvelek
# 9248   Super built-up  Area  Ready To Move  Kalena Agrahara  3 BHK  Mykyayi
# 11115  Super built-up  Area  Ready To Move           Harlur  2 BHK  Prncyrn
# 10619  Super built-up  Area  Ready To Move     Malleshwaram  2 BHK      NaN
# 4562   Super built-up  Area  Ready To Move       HMT Layout  3 BHK  LoentKr
#
#       total_sqft  bath  balcony  price
# 694         1240   2.0      2.0   60.0
# 9248        1902   3.0      2.0   89.0
# 11115       1197   2.0      1.0   77.0
# 10619       1020   2.0      1.0   80.0
# 4562        1650   3.0      2.0   75.0

# %%
# finding the information o fthe data with null values and all other details


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7819 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
# statistical information of the dataset

df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %% [markdown]
# #  observation from the dataset
#
# #  only three columns are having the continous data

# %%
# correlation between diffrent columns of the dataset

df.corr()
# Out:
#              bath   balcony     price
# bath     1.000000  0.204201  0.456345
# balcony  0.204201  1.000000  0.120355
# price    0.456345  0.120355  1.000000

# %% [markdown]
# # observation:  if bath  increase by 20% then price of house will
# # increase by 45% of the total base amount

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5501
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# # Data preprocessing:

# %%
df['society']
# Out:
# 0        Coomee
# 1        Theanmp
# 2         @@@@@@
# 3        Soiewre
# 4            NaN
#           ...
# 13315    ArsiaEx
# 13316        NaN
# 13317    Mahla T
# 13318    SollyCl
# 13319        NaN
# Name: society, Length: 13320, dtype: object

# %%
df['society'].mode()[0]
# Out:
# 'GrrvaGr'

# %%
df['society'].fillna(df['society'].mode()[0],inplace=True)  # handling missing values in society column

# %%
df['society'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df['location'].dtype
# Out:
# dtype('O')

# %%
df['location'].fillna(df['location'].mode()[0],inplace=True)  # handling missing values in location column

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size             16
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df['size'].dtype
# Out:
# dtype('O')

# %%
df['size'].fillna(df['size'].mode()[0],inplace=True)   # handling missing values in size column

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df['bath'].dtype
# Out:
# dtype('float64')

# %%
df['bath'].fillna(float(int(df['bath'].mean())),inplace=True)   # handling missing values in bath column

# %%
df['bath'].mean()
# Out:
# 2.688813813813814

# %%
float(int(df['bath'].mean()))
# Out:
# 2.0

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath              0
# balcony         609
# price             0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['balcony'].fillna(df['balcony'].median(),inplace=True)   # handling missing values in balcony column

# %%
df['balcony'].median()
# Out:
# 2.0

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64
