# %%
import pandas as pd

# %%
df=pd.read_csv('Indian Startup.csv')

# %%
df.head(10)
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
# 6     Pocket FM   2018.0    Bangalore                               OTT
# 7   CHARGE+ZONE   2018.0     Vadodara                        Automotive
# 8   PlanetSpark   2017.0     Gurugram              Education Management
# 9    LenDenClub   2015.0       Mumbai                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# ...

# %%
df.tail(10)
# Out:
#          Company/Brand  Founded Headquarters         Sector  \
# 1199             Udaan   2016.0    Bangalore     E-commerce
# 1200      Vanity Wagon   2018.0      Haryana      Cosmetics
# 1201               Oyo   2012.0      Gurgaon    Hospitality
# 1202           Agri10x   2018.0         Pune       AgriTech
# 1203         BlackSoil   2016.0       Mumbai        FinTech
# 1204          HobSpace   2019.0       Mumbai         EdTech
# 1205           DcodeAI   2020.0    New Delhi         EdTech
# 1206  Biocon Biologics   1978.0    Bangalore  BioTechnology
# 1207        KiranaKart   2020.0       Mumbai     E-commerce
# 1208             Meddo   2018.0      Gurgaon     Healthcare
#
#                                            What it does  \
# 1199  Udaan is a B2B trade platform that brings manu...
# 1200  Vanity Wagon is India’s #1 Natural Organic Bea...
# 1201  OYO operates a branded network of hotels desig...
# 1202  Agri10x integrates the entire Agri value-chain...
# ...

# %% [markdown]
# # explore the data

# %%
df.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %%
df.shape
# Out:
# (1209, 10)

# %% [markdown]
# # observation:
# # 1: founded feature is treated as float
# # 2: amount feature is treated as categorical and having irrelavant data disclosed by $
# # 3: no co-relation
# # 4: null values

# %%
# loc and iloc

# %%
df.loc[0]  # it will the complete information of first row
# Out:
# Company/Brand                                         CollegeDekho
# Founded                                                     2015.0
# Headquarters                                               Gurgaon
# Sector                                                  E-learning
# What it does     Collegedekho.com is Student’s Partner, Friend ...
# Founder/s                                             Ruchir Arora
# Investor/s                                        Disrupt ADQ, QIC
# Amount                                                 $35,000,000
# Stage                                                     Series B
# Date                                                      Dec-2021
# Name: 0, dtype: object

# %%
df.loc[0:10]
# Out:
#    Company/Brand  Founded Headquarters                            Sector  \
# 0   CollegeDekho   2015.0      Gurgaon                        E-learning
# 1           BOX8   2012.0       Mumbai                  Food & Beverages
# 2          Simpl   2015.0    Bangalore                 Consumer Services
# 3    8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4      PayGlocal   2021.0    Bangalore                Financial Services
# 5        Curefit   2016.0    Bangalore        Health, Wellness & Fitness
# 6      Pocket FM   2018.0    Bangalore                               OTT
# 7    CHARGE+ZONE   2018.0     Vadodara                        Automotive
# 8    PlanetSpark   2017.0     Gurugram              Education Management
# 9     LenDenClub   2015.0       Mumbai                Financial Services
# 10     CometChat   2009.0       Mumbai                 Computer Software
#
#                                          What it does  \
# ...

# %%
df.loc[df['Sector']=='EdTech'][:10]
# Out:
#            Company/Brand  Founded Headquarters  Sector  \
# 186               BYJU'S   2011.0    Bangalore  EdTech
# 192  Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254               Questt   2020.0     Gurugram  EdTech
# 372            EventBeep   2019.0         Pune  EdTech
# 382             Tinkerly   2015.0       Jaipur  EdTech
# 396      Genext Students   2013.0       Mumbai  EdTech
# 401            OckyPocky   2015.0     Gurugram  EdTech
# 409             Codingal   2020.0    Bangalore  EdTech
# 415               Habbit   2020.0    Bangalore  EdTech
# 419             Vidyakul   2017.0     Gurugram  EdTech
#
#                                           What it does  \
# 186  BYJU’S is India's largest ed-tech company and ...
# 192  Sunstone Eduversity is a one-of-its-kind busin...
# 254  Questt is a Free online homework app that lets...
# 372  An inclusive community where students are insp...
# 382  A STEM learning online-offline solutions provi...
# ...

# %%
df.loc[df['Sector']=='EdTech'][:10:2]
# Out:
#     Company/Brand  Founded Headquarters  Sector  \
# 186        BYJU'S   2011.0    Bangalore  EdTech
# 254        Questt   2020.0     Gurugram  EdTech
# 382      Tinkerly   2015.0       Jaipur  EdTech
# 401     OckyPocky   2015.0     Gurugram  EdTech
# 415        Habbit   2020.0    Bangalore  EdTech
#
#                                           What it does  \
# 186  BYJU’S is India's largest ed-tech company and ...
# 254  Questt is a Free online homework app that lets...
# 382  A STEM learning online-offline solutions provi...
# 401  OckyPocky is India's 1st interactive English l...
# 415  Habbit is online learning community for anyone...
#
#                                              Founder/s  \
# 186                   Byju Raveendran, Divya Gokulnath
# 254                       Akhil, Mohsin M, Rohit Pande
# 382  O.P. Godara, Vivek Pathak, Kapil Arya, Sharad ...
# 401                                       Amit Agrawal
# 415                      Somnath Sandeep, Raghav Goyal
#
# ...

# %%
#iloc

# %%
# dif b/w loc and iloc

# %%
# iloc= 'index based location'

# %%
df.loc[df['Sector']=='EdTech'].iloc[4:9]
# Out:
#        Company/Brand  Founded Headquarters  Sector  \
# 382         Tinkerly   2015.0       Jaipur  EdTech
# 396  Genext Students   2013.0       Mumbai  EdTech
# 401        OckyPocky   2015.0     Gurugram  EdTech
# 409         Codingal   2020.0    Bangalore  EdTech
# 415           Habbit   2020.0    Bangalore  EdTech
#
#                                           What it does  \
# 382  A STEM learning online-offline solutions provi...
# 396  LIVE online classes with expert tutors for K-1...
# 401  OckyPocky is India's 1st interactive English l...
# 409  Codingal is on a mission to inspire school kid...
# 415  Habbit is online learning community for anyone...
#
#                                              Founder/s  \
# 382  O.P. Godara, Vivek Pathak, Kapil Arya, Sharad ...
# 396                    Ali Asgar Kagzi, Piyush Dhanuka
# 401                                       Amit Agrawal
# 409                     Vivek Prakash, Satyam Baranwal
# ...

# %%
# groupby
# merge
# append
# concate
# join

# %%
# using groupby group the number of startups in gurgaon

# %%
df.groupby(by="Headquarters").mean()
# Out:
#                         Founded
# Headquarters
# Ahmadabad           2016.500000
# Ahmedabad           2016.000000
# Ambernath           2016.000000
# Andheri             2019.000000
# Bangalore           2017.192488
# ...                         ...
# The Nilgiris        2016.000000
# Thiruvananthapuram  2016.000000
# Trivandrum          2021.000000
# Vadodara            2018.000000
# West Bengal         2019.000000
#
# [70 rows x 1 columns]

# %%
# to find the sector present excatly in gurgaon

df.loc[df['Headquarters']=='Gurgaon'].groupby(['Headquarters','Sector']).mean()
# Out:
#                                 Founded
# Headquarters Sector
# Gurgaon      B2B Manufacturing   2020.0
#              E-learning          2015.0
#              EdTech              2019.0
#              FinTech             2018.0
#              Gaming              2018.0
#              Healthcare          2018.0
#              Hospitality         2012.0
