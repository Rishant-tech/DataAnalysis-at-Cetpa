# %%
# loc- location

# iloc- location by indexing

# purpose- searching in the data

# %%
import pandas as pd

# %%
df=pd.read_csv('IPL Matches 2008-2020.csv')

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
df.sample()
# Out:
#          id    city        date player_of_match             venue  \
# 384  598060  Mumbai  2013-05-13      KA Pollard  Wankhede Stadium
#
#      neutral_venue           team1                team2          toss_winner  \
# 384              0  Mumbai Indians  Sunrisers Hyderabad  Sunrisers Hyderabad
#
#     toss_decision          winner   result  result_margin eliminator method  \
# 384           bat  Mumbai Indians  wickets            7.0          N    NaN
#
#           umpire1     umpire2
# 384  AK Chaudhary  SJA Taufel

# %%
df.loc(df['player_of_match'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.loc(df['player_of_match'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     546 @final
#     547 @classmethod
#     548 def _get_axis_number(cls, axis: Axis) -> int:
#     549     try:
# --> 550         return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551     except KeyError:
#     552         raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ...

# %%
df.groupby(by=['city','player_of_match']).mean().iloc[:50]
# Out:
#                                      id  neutral_venue  result_margin
# city      player_of_match
# Abu Dhabi A Nortje         1.216505e+06            0.0       6.000000
#           AM Rahane        7.292850e+05            1.0       4.000000
#           AT Rayudu        1.216492e+06            0.0       5.000000
#           BA Stokes        1.216539e+06            0.0       7.500000
#           CV Varun         1.216497e+06            0.0      59.000000
#           GJ Maxwell       7.292830e+05            1.0       6.000000
#           JC Buttler       1.216533e+06            0.0       7.000000
#           JH Kallis        7.292790e+05            1.0      41.000000
#           JP Faulkner      7.293150e+05            1.0            NaN
#           KA Pollard       1.216503e+06            0.0      48.000000
#           KD Karthik       1.216523e+06            0.0       2.000000
#           KS Williamson    1.237178e+06            0.0       6.000000
# ...

# %%
# concate
# append
# merge

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 concate(a,b)
#
# NameError: name 'concate' is not defined
